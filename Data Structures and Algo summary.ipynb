# %% [markdown]
# ### Arrays

# %% [markdown]
# #### different data structures in languages

# %% [markdown]
# ![dataStructures.png](attachment:dataStructures.png)

# %% [markdown]
# ### Arrays vs LinkedList

# %% [markdown]
# ![arrayVslinkedlist.png](attachment:arrayVslinkedlist.png)
